# %% [markdown]
# ## Time Series Analysis
#
# ### What is a Time Series?
# Time series is a sequence of observations recorded at regular time intervals. It could be hourly, daily, weekly or even monthly depending on the data.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil.parser import parse

# %% [markdown]
# #### Printing the Dataset

# %%
dataset = pd.read_excel('dataset.xlsx')
print(dataset)
# Out:
#        Actual      time
# 0      -0.128  06:00:00
# 1       5.760  06:15:00
# 2      11.136  06:30:00
# 3      14.336  06:45:00
# 4      33.792  07:00:00
# 5      35.456  07:15:00
# 6      44.288  07:30:00
# 7      61.056  07:45:00
# 8      64.384  08:00:00
# 9      84.352  08:15:00
# 10     89.856  08:30:00
# 11    107.392  08:45:00
# 12    115.072  09:00:00
# 13    109.056  09:15:00
# 14    117.376  09:30:00
# 15    123.520  09:45:00
# 16    138.368  10:00:00
# 17    151.296  10:15:00
# 18    143.360  10:30:00
# 19    111.616  10:45:00
# 20    130.304  11:00:00
# 21    144.256  11:15:00
# 22    141.184  11:30:00
# 23    164.864  11:45:00
# 24    183.424  12:00:00
# 25    169.344  12:15:00
# 26    145.024  12:30:00
# 27    113.408  12:45:00
# 28     78.080  13:00:00
# 29    108.416  13:15:00
# ...       ...       ...
# 1755  191.616  11:15:00
# 1756  174.848  11:30:00
# 1757  142.464  11:45:00
# 1758  151.296  12:00:00
# 1759  152.960  12:15:00
# 1760  147.200  12:30:00
# ...

# %% [markdown]
# #### Plotting the data using Matplotlib

# %%
def plot_df(df, x, y, title="", xlabel='Time', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
plot_df(dataset, x = dataset.time, y = dataset.Actual)

# %% [markdown]
# It can be observed from this model that the solar levels tends to zero at the start of the day and further towards the mid day various flucations are observed. In future, a simple linear regression model can be established to predict the behaviour of such a system
